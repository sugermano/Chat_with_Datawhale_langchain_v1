# %%
import sys 
# import llm.wenxin_llm
sys.path.append("D:/gitRepository/Chat_with_Datawhale_langchain")
# from Wenxin_LLM
# import llm
from llm.wenxin_llm import Wenxin_LLM
from Chat_QA_chain_self import Chat_QA_chain_self #带历史记录的问答链
from QA_chain_self import QA_chain_self       #不带历史记录的问答链

# %%
import os
# os.environ

# %% [markdown]
# ## 带历史记录的问答链

# %%
# 定义参数
# model可选值：["gpt-3.5-turbo", "gpt-3.5-turbo-16k-0613", "gpt-3.5-turbo-0613", "gpt-4", "gpt-4-32k"]，["ERNIE-Bot", "ERNIE-Bot-4", "ERNIE-Bot-turbo"]，
# ["Spark-1.5", "Spark-2.0"]，["chatglm_pro", "chatglm_std", "chatglm_lite"]
# "D:\gitRepository\llm-universe"
model:str = "glm-4-plus"
temperature:float=0.0
top_k:int=4 
chat_history:list=[] 
file_path:str = "D:/gitRepository/llm-universe/data_base/knowledge_db"
persist_path:str = "D:/gitRepository/llm-universe/data_base/vector_db/chroma"
appid:str=None 
api_key:str = "a7db401f88674a27a06a5d4698e0550d.Vd0YaLGBb0cRHegy"   #or 从本地环境读取
api_secret:str=None 
embedding = "zhipuai"     # ["openai","zhipuai", "m3e"]  默认m3e
embedding_key = ""

# %%
qa_chain = Chat_QA_chain_self(model=model, temperature=temperature, top_k=top_k, chat_history=chat_history, file_path=file_path, persist_path=persist_path, api_key=api_key, embedding = embedding, embedding_key=embedding_key)
print(qa_chain)
# Out:
# D:\gitRepository/Chat_with_Datawhale_langchain\database\create_db.py:114: LangChainDeprecationWarning: The class `Chroma` was deprecated in LangChain 0.2.9 and will be removed in 1.0. An updated version of the class exists in the `langchain-chroma package and should be used instead. To use it run `pip install -U `langchain-chroma` and import as `from `langchain_chroma import Chroma``.
#   vectordb = Chroma(
# <Chat_QA_chain_self.Chat_QA_chain_self object at 0x00000187FE291D90>

# %% [markdown]
# ### 第一轮

# %%
question = "我可以学习到关于强化学习的知识吗？"
#answer,chat_history = qa_chain.answer(question)
answer = qa_chain.answer(question)
# Out:
# 我可以学习到关于强化学习的知识吗？

# %%
print(answer)
print(chat_history)
# Out:
# [('我可以学习到关于强化学习的知识吗？', '是的，你可以从提供的文本中学习到关于强化学习的基础知识。文本中包含了强化学习的基本概念、术语、以及一些经典算法的介绍和公式推导。具体来说，你可以了解到以下内容：\n\n1. **任务与奖赏**：了解强化学习的定义和相关术语。\n2. **K-摇臂赌博机**：包括公式推导和解释，帮助你理解探索与利用的平衡。\n3. **有模型学习**：虽然具体内容未详细展开，但提到了相关公式和概念。\n\n此外，文本还推荐了其他书籍如《Easy RL：强化学习教程》进行更系统性的学习，并且提供了配套视频教程的链接，可以帮助你更深入地理解和掌握强化学习。\n\n如果你对某个具体部分有疑问或需要更详细的解释，可以进一步提问。')]
# [('我可以学习到关于强化学习的知识吗？', '是的，你可以从提供的文本中学习到关于强化学习的基础知识。文本中包含了强化学习的基本概念、术语、以及一些经典算法的介绍和公式推导。具体来说，你可以了解到以下内容：\n\n1. **任务与奖赏**：了解强化学习的定义和相关术语。\n2. **K-摇臂赌博机**：包括公式推导和解释，帮助你理解探索与利用的平衡。\n3. **有模型学习**：虽然具体内容未详细展开，但提到了相关公式和概念。\n\n此外，文本还推荐了其他书籍如《Easy RL：强化学习教程》进行更系统性的学习，并且提供了配套视频教程的链接，可以帮助你更深入地理解和掌握强化学习。\n\n如果你对某个具体部分有疑问或需要更详细的解释，可以进一步提问。')]

# %% [markdown]
# ### 第二轮

# %%
question = "为什么这门课需要教这方面的知识？"
answer,chat_history = qa_chain.answer(question)
# Out:
# 为什么需要教授关于强化学习的知识？

# %%
print(answer)
print(chat_history)
# Out:
# ('我可以学习到关于强化学习的知识吗？', '是的，你可以从提供的文本中学习到关于强化学习的基础知识。文本中包含了强化学习的基本概念、术语、以及一些经典算法的介绍和公式推导。具体来说，你可以了解到以下内容：\n\n1. **任务与奖赏**：了解强化学习的定义和相关术语。\n2. **K-摇臂赌博机**：包括公式推导和解释，帮助你理解探索与利用的平衡。\n3. **有模型学习**：虽然具体内容未详细展开，但提到了相关公式和概念。\n\n此外，文本还推荐了其他书籍如《Easy RL：强化学习教程》进行更系统性的学习，并且提供了配套视频教程的链接，可以帮助你更深入地理解和掌握强化学习。\n\n如果你对某个具体部分有疑问或需要更详细的解释，可以进一步提问。')
# ('为什么这门课需要教这方面的知识？', '教授关于强化学习的知识是必要的，原因如下：\n\n1. **完整的理论体系**：强化学习作为机器学习的一个重要子领域，拥有自己的一套完整理论体系。了解这些理论基础对于深入掌握机器学习领域至关重要。\n\n2. **广泛应用**：强化学习在多个领域都有广泛应用，如自动驾驶、游戏AI、机器人控制、推荐系统等。掌握强化学习知识可以更好地解决这些领域的实际问题。\n\n3. **前沿算法**：强化学习领域不断有新的前沿算法被提出，了解这些算法可以帮助研究人员和工程师保持技术领先。\n\n4. **综合能力培养**：强化学习涉及决策过程、动态环境适应等多方面能力，学习强化学习有助于培养综合分析和解决问题的能力。\n\n5. **系统学习需求**：如文中所提到的，“西瓜书”的相关章节仅作为综述查阅，若想深究，需要查阅其他书籍进行系统性学习。这表明强化学习的复杂性需要系统化的教学。\n\n6. **理论与实践结合**：通过学习强化学习，可以将理论知识与实际应用结合起来，提升实践能力和创新能力。\n\n综上所述，教授强化学习知识不仅有助于学生和研究人员建立扎实的理论基础，还能提升他们在实际应用中的能力和竞争力。')

# %% [markdown]
# ### 改变历史记录的长度

# %%
history_len = 1 

### 改变历史记录的长度,使用的是history_len参数来改变保留历史记录的长度
chat_history = qa_chain.change_history_length(history_len)
print(chat_history)
# Out:
# [('为什么这门课需要教这方面的知识？', '教授关于强化学习的知识是必要的，原因如下：\n\n1. **完整的理论体系**：强化学习作为机器学习的一个重要子领域，拥有自己的一套完整理论体系。了解这些理论基础对于深入掌握机器学习领域至关重要。\n\n2. **广泛应用**：强化学习在多个领域都有广泛应用，如自动驾驶、游戏AI、机器人控制、推荐系统等。掌握强化学习知识可以更好地解决这些领域的实际问题。\n\n3. **前沿算法**：强化学习领域不断有新的前沿算法被提出，了解这些算法可以帮助研究人员和工程师保持技术领先。\n\n4. **综合能力培养**：强化学习涉及决策过程、动态环境适应等多方面能力，学习强化学习有助于培养综合分析和解决问题的能力。\n\n5. **系统学习需求**：如文中所提到的，“西瓜书”的相关章节仅作为综述查阅，若想深究，需要查阅其他书籍进行系统性学习。这表明强化学习的复杂性需要系统化的教学。\n\n6. **理论与实践结合**：通过学习强化学习，可以将理论知识与实际应用结合起来，提升实践能力和创新能力。\n\n综上所述，教授强化学习知识不仅有助于学生和研究人员建立扎实的理论基础，还能提升他们在实际应用中的能力和竞争力。')]

# %% [markdown]
# ### 清除历史记录

# %%
chat_history = qa_chain.clear_history()
print(chat_history)
# Out:
# None

# %% [markdown]
# ## 不带历史记录的问答链

# %%
# 定义参数
# model可选值：["gpt-3.5-turbo", "gpt-3.5-turbo-16k-0613", "gpt-3.5-turbo-0613", "gpt-4", "gpt-4-32k"]，["ERNIE-Bot", "ERNIE-Bot-4", "ERNIE-Bot-turbo"]，
# ["Spark-1.5", "Spark-2.0"]，["chatglm_pro", "chatglm_std", "chatglm_lite"]
model:str = "glm-4-plus"
temperature:float=0.0
top_k:int=4 
file_path:str = "D:/gitRepository/llm-universe/data_base/knowledge_db"
persist_path:str = "D:/gitRepository/llm-universe/data_base/vector_db/chroma"
appid:str=None 
api_key:str = "a7db401f88674a27a06a5d4698e0550d.Vd0YaLGBb0cRHegy"   #or从本地环境读取
api_secret:str=None 
embedding = "zhipuai"
embedding_key = ""

# %%
#星火输入参数用法
#qa_chain = QA_chain_self(model=model, temperature=temperature, top_k=top_k, file_path=file_path, persist_path=persist_path, appid=appid,api_key=api_key,Spark_api_secret=Spark_api_secret, embedding = embedding,embedding_key=embedding_key)

##百度文心输入参数用法
#qa_chain = QA_chain_self(model=model, temperature=temperature, top_k=top_k, file_path=file_path, persist_path=persist_path, appid=appid,api_key=api_key,Wenxin_api_secret=Wenxin_api_secret, embedding = embedding,embedding_key=embedding_key)

#智谱(或OpenAI)输入参数用法
qa_chain = QA_chain_self(model=model, temperature=temperature, top_k=top_k, file_path=file_path, persist_path=persist_path, appid=appid,api_key=api_key, embedding = embedding,embedding_key=embedding_key)
print(qa_chain)
# Out:
# <QA_chain_self.QA_chain_self object at 0x00000187FE789550>

# %%
question = "什么是蘑菇书（easyrl）？"
answer = qa_chain.answer(question)
# Out:
# 什么是蘑菇书（easyrl）？

# %%
print(answer)
# Out:
# 根据您提供的信息，并没有直接提及“蘑菇书（easyrl）”的相关内容。因此，我无法基于这些信息来回答“什么是蘑菇书（easyrl）”的问题。
#
# 不过，我可以提供一些一般性的信息。通常，“蘑菇书”可能是指某个特定领域的书籍或资料，而“easyrl”可能是该书籍的代号或相关项目的名称。在机器学习和强化学习领域，有时会有一些开源项目或学习资料以这样的代号命名，以便于记忆和传播。
#
# 如果您需要了解具体的“蘑菇书（easyrl）”是什么，建议您查找相关的资料或直接访问提到的项目或书籍的官方网站或社区。如果您有更多上下文信息，也可以提供给我，我会尽力帮助您解答。

# %% [markdown]
# ------------------
# > 其他模型可参考上面的实例进行使用，embedding 目前支持 openAI 和智谱以及m3e的模型，其他类型敬请期待！
