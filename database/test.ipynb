# %%
import sys 
sys.path.append("D:/gitRepository/Chat_with_Datawhale_langchain")
from langchain_community.vectorstores import Chroma
from langchain_community.document_loaders import PyMuPDFLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_community.embeddings.openai import OpenAIEmbeddings
from langchain_community.embeddings.huggingface import HuggingFaceEmbeddings
from langchain_community.llms.openai import OpenAI
from langchain_community.llms.huggingface_pipeline import HuggingFacePipeline
from langchain_community.embeddings.sentence_transformer import SentenceTransformerEmbeddings
from embedding.zhipuai_embedding import ZhipuAIEmbeddings

# %%
import os
# import openai

# openai.api_key  = os.environ['OPENAI_API_KEY']
ZHIPUAI_API_KEY = "a7db401f88674a27a06a5d4698e0550d.Vd0YaLGBb0cRHegy"
embedding =ZhipuAIEmbeddings(zhipuai_api_key=ZHIPUAI_API_KEY)
# embedding = OpenAIEmbeddings()

# %%
persist_directory = 'D:/gitRepository/llm-universe/data_base/vector_db/chroma'
vectordb = Chroma(
    persist_directory=persist_directory,
    embedding_function=embedding
)
print(f"向量库中存储的数量：{vectordb._collection.count()}")
# Out:
# C:\Users\18235\AppData\Local\Temp\ipykernel_29476\2171509060.py:2: LangChainDeprecationWarning: The class `Chroma` was deprecated in LangChain 0.2.9 and will be removed in 1.0. An updated version of the class exists in the `langchain-chroma package and should be used instead. To use it run `pip install -U `langchain-chroma` and import as `from `langchain_chroma import Chroma``.
#   vectordb = Chroma(
# 向量库中存储的数量：1004

# %%
question="llm_universe"
sim_docs = vectordb.similarity_search(question, k=10)
print(sim_docs)
# print(f"检索到的内容数：{len(sim_docs)}")
# Out:
# llm_universe
# [Document(metadata={'file_path': '../../data_base/knowledge_db/pumkin_book/pumpkin_book.pdf', 'modDate': '', 'format': 'PDF 1.5', 'keywords': '', 'creator': 'LaTeX with hyperref', 'source': '../../data_base/knowledge_db/pumkin_book/pumpkin_book.pdf', 'author': '', 'creationDate': "D:20230303170709-00'00'", 'page': 112, 'title': '', 'producer': 'xdvipdfmx (20200315)', 'subject': '', 'trapped': '', 'total_pages': 196}, page_content='←_←'), Document(metadata={'author': '', 'modDate': '', 'total_pages': 196, 'trapped': '', 'source': '../../data_base/knowledge_db/pumkin_book/pumpkin_book.pdf', 'producer': 'xdvipdfmx (20200315)', 'title': '', 'creationDate': "D:20230303170709-00'00'", 'file_path': '../../data_base/knowledge_db/pumkin_book/pumpkin_book.pdf', 'creator': 'LaTeX with hyperref', 'format': 'PDF 1.5', 'subject': '', 'keywords': '', 'page': 179}, page_content='←_←'), Document(metadata={'modDate': '', 'total_pages': 196, 'creationDate': "D:20230303170709-00'00'", 'producer': 'xdvipdfmx (20200315)', 'author': '', 'file_path': '../../data_base/knowledge_db/pumkin_book/pumpkin_book.pdf', 'creator': 'LaTeX with hyperref', 'page': 2, 'subject': '', 'trapped': '', 'title': '', 'keywords': '', 'format': 'PDF 1.5', 'source': '../../data_base/knowledge_db/pumkin_book/pumpkin_book.pdf'}, page_content='23\n→_→\n配套视频教程：https://www.bilibili.com/video/BV1Mh411e7VU\n←_←'), Document(metadata={'source': '../../data_base/knowledge_db/prompt_engineering/6. 文本转换 Transforming.md'}, page_content='5.1 综合样例'), Document(metadata={'title': '', 'producer': 'xdvipdfmx (20200315)', 'subject': '', 'creationDate': "D:20230303170709-00'00'", 'format': 'PDF 1.5', 'trapped': '', 'total_pages': 196, 'page': 11, 'keywords': '', 'file_path': '../../data_base/knowledge_db/pumkin_book/pumpkin_book.pdf', 'modDate': '', 'author': '', 'source': '../../data_base/knowledge_db/pumkin_book/pumpkin_book.pdf', 'creator': 'LaTeX with hyperref'}, page_content='179\n→_→\n配套视频教程：https://www.bilibili.com/video/BV1Mh411e7VU\n←_←'), Document(metadata={'total_pages': 196, 'subject': '', 'source': '../../data_base/knowledge_db/pumkin_book/pumpkin_book.pdf', 'format': 'PDF 1.5', 'author': '', 'file_path': '../../data_base/knowledge_db/pumkin_book/pumpkin_book.pdf', 'creationDate': "D:20230303170709-00'00'", 'producer': 'xdvipdfmx (20200315)', 'title': '', 'keywords': '', 'modDate': '', 'page': 7, 'creator': 'LaTeX with hyperref', 'trapped': ''}, page_content='118\n→_→\n配套视频教程：https://www.bilibili.com/video/BV1Mh411e7VU\n←_←'), Document(metadata={'subject': '', 'format': 'PDF 1.5', 'modDate': '', 'page': 175, 'author': '', 'creationDate': "D:20230303170709-00'00'", 'creator': 'LaTeX with hyperref', 'trapped': '', 'file_path': '../../data_base/knowledge_db/pumkin_book/pumpkin_book.pdf', 'source': '../../data_base/knowledge_db/pumkin_book/pumpkin_book.pdf', 'keywords': '', 'producer': 'xdvipdfmx (20200315)', 'title': '', 'total_pages': 196}, page_content='→_→\n配套视频教程：https://www.bilibili.com/video/BV1Mh411e7VU\n←_←'), Document(metadata={'modDate': '', 'subject': '', 'file_path': '../../data_base/knowledge_db/pumkin_book/pumpkin_book.pdf', 'producer': 'xdvipdfmx (20200315)', 'creator': 'LaTeX with hyperref', 'author': '', 'page': 168, 'format': 'PDF 1.5', 'title': '', 'total_pages': 196, 'source': '../../data_base/knowledge_db/pumkin_book/pumpkin_book.pdf', 'creationDate': "D:20230303170709-00'00'", 'trapped': '', 'keywords': ''}, page_content='→_→\n配套视频教程：https://www.bilibili.com/video/BV1Mh411e7VU\n←_←'), Document(metadata={'source': '../../data_base/knowledge_db/prompt_engineering/4. 文本概括 Summarizing.md'}, page_content='review for a blender'), Document(metadata={'source': '../../data_base/knowledge_db/pumkin_book/pumpkin_book.pdf', 'creator': 'LaTeX with hyperref', 'file_path': '../../data_base/knowledge_db/pumkin_book/pumpkin_book.pdf', 'total_pages': 196, 'subject': '', 'modDate': '', 'page': 120, 'keywords': '', 'trapped': '', 'creationDate': "D:20230303170709-00'00'", 'author':  ...

# %%
for i, sim_doc in enumerate(sim_docs):
    print(f"检索到的第{i}个内容: \n{sim_doc.page_content}", end="\n--------------\n")
# Out:
# 检索到的第0个内容:
# ←_←
# --------------
# 检索到的第1个内容:
# ←_←
# --------------
# 检索到的第2个内容:
# 23
# →_→
# 配套视频教程：https://www.bilibili.com/video/BV1Mh411e7VU
# ←_←
# --------------
# 检索到的第3个内容:
# 5.1 综合样例
# --------------
# 检索到的第4个内容:
# 179
# →_→
# 配套视频教程：https://www.bilibili.com/video/BV1Mh411e7VU
# ←_←
# --------------
# 检索到的第5个内容:
# 118
# →_→
# 配套视频教程：https://www.bilibili.com/video/BV1Mh411e7VU
# ←_←
# --------------
# 检索到的第6个内容:
# →_→
# 配套视频教程：https://www.bilibili.com/video/BV1Mh411e7VU
# ←_←
# --------------
# 检索到的第7个内容:
# →_→
# 配套视频教程：https://www.bilibili.com/video/BV1Mh411e7VU
# ←_←
# --------------
# 检索到的第8个内容:
# review for a blender
# --------------
# 检索到的第9个内容:
# a11
# a21
# · · ·
# ai1
# · · ·
# am1
# a12
# a22
# · · ·
# ai2
# · · ·
# am2
# ...
# ...
# ...
# ...
# ...
# ...
# a1j
# a2j
# · · ·
# aij
# · · ·
# amj
# ...
# ...
# ...
# ...
# ...
# ...
# a1n
# a2n
# · · ·
# ain
# · · ·
# amn
# 
# 
# →_→
# 配套视频教程：https://www.bilibili.com/video/BV1Mh411e7VU
# ←_←
# --------------
